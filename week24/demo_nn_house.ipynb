# %%
# B1: đọc dữ liệu, khám phá dữ liệu, xem các cột nào số, cột nào object, 
#

# %%
# B2: xử lý dữ liệu thiếu (2 loại: số và object)

# %%
# B3: Mã hóa dữ liệu object (LabelEncoder)

# %%
# B4: Chuẩn hóa dữ liệu số (StandardScaler)

# %%
# B5: Xây dựng mạng nơ-ron nhân tạo (ANN) với Keras để dự đoán giá nhà
# 5.1 Dự báo chính xác: dùng hàm kích hoạt 'linear' (None), loss là MSE
# 5.2 Nếu dự báo theo khoảng giá thì dùng 'softmax', loss là cross entropy

# %%
# B6: Đánh giá mô hình
# Dự báo chính xác giá nhà: RMSE, MAE
# Dự báo khoảng giá nhà: Accuracy, F1-score, Confusion Matrix
